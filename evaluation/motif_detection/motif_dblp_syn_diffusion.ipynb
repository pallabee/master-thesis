# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import itertools
import community as community_louvain
import matplotlib.cm as cm
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### DBLP

# %%
path = 'syn_diffusion/dblp/'

# %%
def plot_graph(G):

    color_class_map = {0: 'blue', 1: 'red', 2: 'darkgreen', 3: 'orange'}

    nx.draw(G, 
        with_labels=False, node_color=[color_class_map[node[1]['color_val']] 
                        for node in G.nodes(data=True)], 
            node_size=200,
        font_color='white')
    plt.show()

# %%
def plot_partition(G,partition):
    # draw the graph
    pos = nx.spring_layout(G)
    # color the nodes according to their partition
    cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
    nx.draw_networkx_nodes(G, pos, partition.keys(), node_size=100,label=True,
                            cmap=cmap, node_color=list(partition.values()))
    nx.draw_networkx_edges(G, pos, alpha=0.5)
    plt.show()

# %%
def detect_community(G):
    partition = community_louvain.best_partition(G)
    plot_partition(G,partition)

# %% [markdown]
# Graph of 10 nodes

# %%
G10 = nx.read_gexf(path + 'graph_1.gexf')
plot_graph(G10)

# %%
detect_community(G10)
list_com= nx.community.louvain_communities(G10, seed=123)
list_com
# Out:
# [{'1', '4'}, {'0', '2', '3', '5', '6', '7', '8', '9'}]

# %%
#Largest substructure
H = G10.subgraph(max(list_com, key=len))
plot_graph(H)

# %% [markdown]
# Graph of 15 nodes

# %%
G15 = nx.read_gexf(path + 'graph_122.gexf')
plot_graph(G15)

# %%
detect_community(G15)
list_com= nx.community.louvain_communities(G15, seed=123)
list_com
# Out:
# [{'0', '10', '12', '2', '8'},
#  {'1', '4', '6'},
#  {'11', '13', '3', '9'},
#  {'14', '5', '7'}]

# %%
#Largest substructure
H = G15.subgraph(max(list_com, key=len))
plot_graph(H)

# %% [markdown]
# Graph of 20 nodes

# %%
G20 = nx.read_gexf(path + 'graph_13.gexf')
plot_graph(G20)

# %%
detect_community(G20)
list_com= nx.community.louvain_communities(G20, seed=123)
list_com
# Out:
# [{'0', '11', '5'},
#  {'12', '14', '16', '17', '2', '4'},
#  {'10', '13', '15', '18', '3', '6', '8'},
#  {'1', '19', '7', '9'}]

# %%
#Largest substructure
H = G20.subgraph(max(list_com, key=len))
plot_graph(H)

# %% [markdown]
# Graph of 25 nodes

# %%
G25 = nx.read_gexf(path + 'graph_19.gexf')
plot_graph(G25)

# %%
detect_community(G25)
list_com= nx.community.louvain_communities(G25, seed=123)
list_com
# Out:
# [{'0', '1', '10', '15', '16', '23', '7'},
#  {'13', '14', '18', '2', '3', '5'},
#  {'12', '19', '22', '4'},
#  {'20', '21', '24', '8'},
#  {'11', '17', '6', '9'}]

# %%
H = G25.subgraph(max(list_com, key=len))
plot_graph(H)

# %% [markdown]
# Graph of 30 nodes

# %%
G30 = nx.read_gexf(path + 'graph_111.gexf')
plot_graph(G30)

# %%
detect_community(G30)
list_com= nx.community.louvain_communities(G30, seed=123)
list_com
# Out:
# [{'1', '21', '8', '9'},
#  {'14', '16', '18', '23', '28'},
#  {'19', '20', '4', '5'},
#  {'11', '12', '13', '22', '3'},
#  {'0', '10', '2', '6'},
#  {'15', '17', '24', '25', '26', '27', '29', '7'}]

# %%
H = G30.subgraph(max(list_com, key=len))
plot_graph(H)
